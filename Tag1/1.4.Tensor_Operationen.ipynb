# %% [markdown]
# # Tensor Operationen

# %% [markdown]
# ## Tensoroperationen sind stark optimiert

# %%
def naive_relu(x):
    assert len(x.shape) == 2
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]): 
            x[i, j] = max(x[i, j], 0)
    return x

# %%
def naive_add(x, y):
    assert len(x.shape) == 2 
    assert x.shape == y.shape 
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]): 
            x[i, j] += y[i, j]
    return x

# %%
import numpy as np 

x = np.random.random((20, 100)) 
y = np.random.random((20, 100))

# %%
# %timeit z = x + y
# Out:
# 1.3 µs ± 49.5 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit z = naive_add(x, y)
# Out:
# 692 µs ± 38.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
z = x + y
# %timeit zz = np.maximum(z, 0.)
# Out:
# 3.79 µs ± 120 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit zz = naive_relu(z)
# Out:
# 1.03 ms ± 11.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# # Broadcasting Beispiel

# %%
# Die Grundrechenarten und die Anwendung von Funktionen sind elementwise definiert
x = np.random.random((64, 3, 32, 10)) 
y = np.random.random((32, 10))
z = np.maximum(x, y)

# %%
z.shape
# Out:
# (64, 3, 32, 10)

# %%
y
# Out:
# array([[[[0.23040801, 0.74197584, 0.22604452, ..., 0.57613664,
#           0.63934209, 0.15714841],
#          [0.99909803, 0.61152527, 0.38569805, ..., 0.31262246,
#           0.61544011, 0.16926998],
#          [0.91320834, 0.99120814, 0.8651067 , ..., 0.19373665,
#           0.19020087, 0.95932511],
#          ...,
#          [0.17735142, 0.17439246, 0.83941649, ..., 0.61450814,
#           0.86050011, 0.31746739],
#          [0.85764539, 0.32604915, 0.87066634, ..., 0.35218257,
#           0.53543676, 0.57250729],
#          [0.47252049, 0.19896443, 0.55962205, ..., 0.9585874 ,
#           0.70232185, 0.62881542]],
#
#         [[0.91062043, 0.44186983, 0.59572971, ..., 0.65497407,
#           0.01719964, 0.37823115],
#          [0.17608266, 0.39362847, 0.33478845, ..., 0.3363777 ,
#           0.08186139, 0.30138499],
#          [0.25840065, 0.30179062, 0.98826192, ..., 0.44002352,
#           0.12601395, 0.37744491],
#          ...,
#          [0.13051661, 0.05801152, 0.47208917, ..., 0.58161891,
#           0.09940406, 0.06858033],
#          [0.79460823, 0.23830677, 0.84118102, ..., 0.38124628,
#           0.68091454, 0.52267952],
#          [0.69192058, 0.49686186, 0.33590272, ..., 0.22294143,
#           0.51708325, 0.78921885]],
#
#         [[0.78280605, 0.26881104, 0.35043138, ..., 0.43163574,
#           0.92791506, 0.29373673],
#          [0.91312808, 0.83898633, 0.23019918, ..., 0.13338401,
#           0.64185717, 0.71411953],
#          [0.04976274, 0.20140068, 0.81827836, ..., 0.32229801,
#           0.01585436, 0.02639295],
#          ...,
#          [0.17897054, 0.62949965, 0.12706394, ..., 0.32260527,
#           0.63851773, 0.53329983],
#          [0.54358168, 0.57736239, 0.16335512, ..., 0.57220971,
#           0.55944342, 0.89132915],
#          [0.55613785, 0.55173576, 0.97803271, ..., 0.14711372,
#           0.20690873, 0.89014145]]],
#
#
#        [[[0.0526704 , 0.41443524, 0.93484703, ..., 0.24434114,
#           0.62706732, 0.03238824],
#          [0.98465369, 0.17848468, 0.85206411, ..., 0.51822102,
#           0.63077613, 0.16225484],
#          [0.73882343, 0.15998021, 0.66758973, ..., 0.83369444,
#           0.20685153, 0.88217874],
#          ...,
#          [0.67477541, 0.22579303, 0.38062552, ..., 0.66542591,
#           0.31470218, 0.24027216],
#          [0.67398243, 0.09012672, 0.94032193, ..., 0.5221263 ,
#           0.85860589, 0.54688285],
#          [0.20656612, 0.9012603 , 0.3599884 , ..., 0.2853485 ,
#           0.41050669, 0.40172383]],
#
#         [[0.15229622, 0.05908662, 0.19528158, ..., 0.79537133,
#           0.64859031, 0.47537355],
#          [0.49731736, 0.03148608, 0.86403607, ..., 0.20628468,
#           0.40524592, 0.17079542],
#          [0.79732597, 0.52989009, 0.73704398, ..., 0.21328651,
#           0.69292798, 0.54797551],
#          ...,
#          [0.83044712, 0.95670471, 0.75950847, ..., 0.4629514 ,
#           0.43364905, 0.47013884],
#          [0.16985538, 0.20501876, 0.19191249, ..., 0.40757661,
#           0.70488702, 0.47907613],
#          [0.38717832, 0.25212596, 0.57534663, ..., 0.2961906 ,
#           0.75153601, 0.84244519]],
#
#         [[0.60222631, 0.60823353, 0.96732576, ..., 0.32686971,
#           0.00195844, 0.50858339],
#          [0.159296  , 0.44782127, 0.12576443, ..., 0.47943822,
#           0.28932258, 0.48221783],
#          [0.57346786, 0.70054351, 0.29358472, ..., 0.12457552,
#           0.74279944, 0.06830693],
#          ...,
#          [0.0131957 , 0.75863002, 0.60624109, ..., 0.0809482 ,
#           0.65524745, 0.29809331],
#          [0.05279604, 0.41585227, 0.71174497, ..., 0.7546722 ,
#           0.36535841, 0.01896649],
#          [0.04025151, 0.54909975, 0.55526403, ..., 0.71714495,
#           0.28650839, 0.37609788]]],
#
#
#        [[[0.36814773, 0.07880466, 0.32872695, ..., 0.373173  ,
#           0.91924333, 0.46123011],
#          [0.79844776, 0.23195785, 0.60307732, ..., 0.69717445,
#           0.17016748, 0.50434883],
#          [0.86004969, 0.38359331, 0.38514378, ..., 0.23651238,
#           0.68629434, 0.92906801],
#          ...,
#          [0.5317873 , 0.15661941, 0.65373094, ..., 0.84897988,
#           0.87682977, 0.00532432],
#          [0.8021812 , 0.49412439, 0.91788142, ..., 0.44708246,
#           0.72957843, 0.21087267],
#          [0.23586016, 0.13168067, 0.94374325, ..., 0.02226203,
#           0.88742235, 0.54918098]],
#
#         [[0.25543238, 0.40997617, 0.92992058, ..., 0.16899293,
#           0.40195194, 0.63017012],
#          [0.60595114, 0.88718415, 0.39364501, ..., 0.51695207,
#           0.65598335, 0.3812069 ],
#          [0.60757191, 0.93440154, 0.30101145, ..., 0.16706435,
#           0.67421427, 0.01277277],
#          ...,
#          [0.84100107, 0.50944577, 0.84732192, ..., 0.45021609,
#           0.30287126, 0.90481865],
#          [0.41782716, 0.02835976, 0.66735696, ..., 0.03546652,
#           0.61418117, 0.24221196],
#          [0.64767128, 0.04560863, 0.42429157, ..., 0.20640047,
#           0.64906156, 0.61912087]],
#
#         [[0.19808083, 0.71463491, 0.27255141, ..., 0.80488881,
#           0.23927438, 0.92897272],
#          [0.76353639, 0.14278118, 0.15081608, ..., 0.65540289,
#           0.30456365, 0.48512177],
#          [0.63828674, 0.55116089, 0.84293292, ..., 0.32318497,
#           0.12093763, 0.14984534],
#          ...,
#          [0.84349209, 0.25465409, 0.8566647 , ..., 0.52937132,
#           0.93610195, 0.9244236 ],
#          [0.62326592, 0.50493819, 0.02633563, ..., 0.54541518,
#           0.75381996, 0.00964293],
#          [0.78905678, 0.61210504, 0.60761447, ..., 0.37409177,
#           0.36074979, 0.33356125]]],
#
#
#        ...,
#
#
#        [[[0.56449931, 0.54477154, 0.85522402, ..., 0.15107309,
#           0.8617915 , 0.73853512],
#          [0.70616611, 0.36778846, 0.0910245 , ..., 0.81967866,
#           0.66867716, 0.98497949],
#          [0.83632618, 0.15365352, 0.24394095, ..., 0.31159746,
#           0.75380453, 0.7220875 ],
#          ...,
#          [0.02332172, 0.1386201 , 0.60927386, ..., 0.69183846,
#           0.13896795, 0.93400459],
#          [0.94640271, 0.78650086, 0.61938387, ..., 0.35188982,
#           0.35682247, 0.26815983],
#          [0.97731679, 0.42212178, 0.2371334 , ..., 0.0961872 ,
#           0.19713285, 0.45250816]],
#
#         [[0.27575489, 0.4361364 , 0.91952482, ..., 0.22697661,
#           0.85527291, 0.96641265],
#          [0.23826739, 0.84867777, 0.25116623, ..., 0.18037662,
#           0.4900862 , 0.12723802],
#          [0.80828196, 0.12350213, 0.87945145, ..., 0.17416793,
#           0.44389671, 0.99307339],
#          ...,
#          [0.01828984, 0.00909338, 0.00430333, ..., 0.19779237,
#           0.191482  , 0.591193  ],
#          [0.63100201, 0.48041404, 0.60895572, ..., 0.4867175 ,
#           0.83460105, 0.78452282],
#          [0.43049249, 0.31162282, 0.3593649 , ..., 0.74984099,
#           0.80594209, 0.36231871]],
#
#         [[0.57272362, 0.74056971, 0.49598398, ..., 0.97856177,
#           0.75795835, 0.8696267 ],
#          [0.57939882, 0.56616929, 0.01905447, ..., 0.59780931,
#           0.59674982, 0.85504841],
#          [0.87510312, 0.14675518, 0.65193284, ..., 0.74744619,
#           0.12534198, 0.42111924],
#          ...,
#          [0.39229117, 0.00299977, 0.99336214, ..., 0.57179957,
#           0.5490332 , 0.19788825],
#          [0.29208852, 0.73272415, 0.87642923, ..., 0.80730245,
#           0.68681319, 0.14372538],
#          [0.09141664, 0.71595544, 0.16361518, ..., 0.38918869,
#           0.02848467, 0.51262993]]],
#
#
#        [[[0.2265514 , 0.71033427, 0.17495728, ..., 0.34045259,
#           0.88530341, 0.87289417],
#          [0.95807443, 0.18510586, 0.0081327 , ..., 0.74564565,
#           0.09356985, 0.79043525],
#          [0.81293866, 0.88206701, 0.23243023, ..., 0.09759344,
#           0.72939948, 0.88216583],
#          ...,
#          [0.30168031, 0.50074844, 0.46844612, ..., 0.2764059 ,
#           0.2110979 , 0.79443992],
#          [0.33003966, 0.47051066, 0.0844806 , ..., 0.32804216,
#           0.64925307, 0.44219569],
#          [0.70015575, 0.90989711, 0.93842665, ..., 0.93522172,
#           0.0609654 , 0.76603823]],
#
#         [[0.24997147, 0.96111587, 0.91455646, ..., 0.44549624,
#           0.77121449, 0.27825098],
#          [0.28730928, 0.41576609, 0.91340131, ..., 0.46588758,
#           0.97498356, 0.90500631],
#          [0.17612089, 0.3559942 , 0.18656388, ..., 0.34803315,
#           0.53214227, 0.01322832],
#          ...,
#          [0.88952739, 0.51679417, 0.23483567, ..., 0.86486753,
#           0.82006172, 0.32977709],
#          [0.78357805, 0.19069052, 0.32490969, ..., 0.77738688,
#           0.72749957, 0.01777038],
#          [0.0090316 , 0.70356647, 0.8041437 , ..., 0.38066615,
#           0.54361116, 0.49912909]],
#
#         [[0.71696771, 0.66586411, 0.52127819, ..., 0.6549434 ,
#           0.54918759, 0.95231781],
#          [0.70413078, 0.58429672, 0.72645746, ..., 0.62371916,
#           0.49672972, 0.27014899],
#          [0.9525516 , 0.39338966, 0.33053116, ..., 0.70465475,
#           0.85680487, 0.63752429],
#          ...,
#          [0.79723618, 0.40840636, 0.91078445, ..., 0.14262357,
#           0.62544607, 0.54788371],
#          [0.99287064, 0.2292171 , 0.90701058, ..., 0.66024486,
#           0.3640137 , 0.88913771],
#          [0.46387833, 0.52482409, 0.54864179, ..., 0.57038903,
#           0.86621266, 0.97892769]]],
#
#
#        [[[0.37620827, 0.13282378, 0.14141679, ..., 0.22672932,
#           0.58682382, 0.91253565],
#          [0.13559281, 0.74813011, 0.24826438, ..., 0.17135285,
#           0.0627625 , 0.4293441 ],
#          [0.24943646, 0.33974044, 0.38386009, ..., 0.17029515,
#           0.26337617, 0.13157845],
#          ...,
#          [0.42614045, 0.07010903, 0.546772  , ..., 0.74199119,
#           0.92082055, 0.69063654],
#          [0.96454386, 0.37219138, 0.91374542, ..., 0.21861192,
#           0.39747697, 0.97690813],
#          [0.31371747, 0.06632312, 0.92132952, ..., 0.98368338,
#           0.45823318, 0.91469013]],
#
#         [[0.33752512, 0.09681871, 0.23140216, ..., 0.25207896,
#           0.88962641, 0.70529772],
#          [0.99742908, 0.57872843, 0.2596644 , ..., 0.46234106,
#           0.49908982, 0.47453289],
#          [0.68941083, 0.99046291, 0.0335369 , ..., 0.13181926,
#           0.38794424, 0.19726427],
#          ...,
#          [0.28991314, 0.11837171, 0.5451569 , ..., 0.99070118,
#           0.3248547 , 0.0892326 ],
#          [0.92322375, 0.42088704, 0.99349486, ..., 0.26401147,
#           0.66462523, 0.42273439],
#          [0.64628794, 0.89495129, 0.77651641, ..., 0.95627145,
#           0.55457097, 0.61254184]],
#
#         [[0.61731863, 0.51400238, 0.88221147, ..., 0.31802503,
#           0.29891828, 0.11563248],
#          [0.57273457, 0.21212767, 0.85578717, ..., 0.00525399,
#           0.7085182 , 0.74785653],
#          [0.24767928, 0.9387441 , 0.25311976, ..., 0.47591635,
#           0.54907513, 0.92758373],
#          ...,
#          [0.88564498, 0.51328197, 0.90560943, ..., 0.31212917,
#           0.70699538, 0.41094873],
#          [0.66687796, 0.02725054, 0.81136633, ..., 0.24838912,
#           0.9229386 , 0.09184142],
#          [0.28653773, 0.92618435, 0.04269141, ..., 0.1670509 ,
#           0.80696724, 0.5520881 ]]]])

# %% [markdown]
# # Dot Produkt

# %%
x = np.random.random((32)) 
y = np.random.random((32)) 
z = np.dot(x, y)

# %%
z.shape
# Out:
# ()

# %%
x = np.random.random((1,32)) 
y = np.random.random((32,1)) 
z = np.dot(x, y)

# %%
z
# Out:
# array([[7.69231973]])

# %%
# VORSICHT! MANCHE MENSCHEN MEINEN DOT-PRODUKT SOLLTE AUCH BEI MATRIZEN SKALAREN OUTPUT HABEN
x = np.random.random((32,5)) 
y = np.random.random((5,32)) 
z = np.dot(x, y)

# %%
z.shape
# Out:
# (32, 32)

# %%
x = np.random.random((9,3,4,8))
y = np.random.random((8,2)) # aber (8,2,3) geht nicht.

z = np.dot(x,y)
z.shape
# Out:
# (9, 3, 4, 2)

# %%
x = np.array([1,2,3]) 
x.shape
# Out:
# (3,)

# %%
def naive_vector_dot(x, y):
    assert len(x.shape) == 1 
    assert len(y.shape) == 1 
    assert x.shape[0] == y.shape[0] 
    
    z = 0.
    for i in range(x.shape[0]): 
        z += x[i] * y[i]
    return z

# %%
def naive_matrix_vector_dot(x, y): 
    assert len(x.shape) == 2 
    assert len(y.shape) == 1 
    assert x.shape[1] == y.shape[0] 
    
    z = np.zeros(x.shape[0])
    for i in range(x.shape[0]): 
        for j in range(x.shape[1]):
            z[i] += x[i, j] * y[j]
    return z

# %% [markdown]
# # Übung
# * Benchmarken der beiden naiven "vector_dot"-Implementierungen vs Numpy
# * Wie ändert sich die Runtime mit der Dimensionalität des Inputs?

# %%
x = np.random.random((8))
y = np.random.random((8)) # aber (8,2,3) geht nicht.
len(x.shape)
x
# Out:
# array([0.89513447, 0.15025122, 0.77060433, 0.10314203, 0.05014465,
#        0.31232442, 0.43535527, 0.21983594])

# %%
# %timeit z = naive_vector_dot(x, y)
# Out:
# 2.97 µs ± 93.4 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit z = np.dot(x,y)
# Out:
# 919 ns ± 40.6 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# Out:
# (8,)

# %% [markdown]
# # Tensor Reshaping

# %%
x = np.array([[0., 1.], 
              [2., 3.],
              [4., 5.]])
x.shape
# Out:
# (3, 2)

# %%
x = x.reshape((6, 1))

# %%
x
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [3.],
#        [4.],
#        [5.]])

# %%
x = x.reshape((2,3))
x
# Out:
# array([[0., 1., 2.],
#        [3., 4., 5.]])

# %%
x = x.reshape((3,2))
x
# Out:
# array([[0., 1.],
#        [2., 3.],
#        [4., 5.]])

# %%
# Aber: transponieren ändert die Reihenfolge
x = x.transpose()
x
# Out:
# array([[0., 2., 4.],
#        [1., 3., 5.]])

# %%
x = x.reshape((3,2))
x
# Out:
# array([[0., 2.],
#        [4., 1.],
#        [3., 5.]])
